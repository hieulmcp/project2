# %%
import lib.step17_RFM as rfm

# %%
# 2. Upload data => name file: House_data.xlsx
dir_file = "data_analysis/OnlineRetail.csv"
datamart, rfm_level_agg = rfm.rfm_model(dir_file)
datamart
# Out:
#       CustomerID  Recency  Frequency  MonetaryValue  R  F  M  RFM_Score  \
# 0        12346.0      327          2           0.00  1  1  1        3.0
# 1        12347.0       41        151        3598.21  2  3  3        8.0
# 2        12348.0       77         31        1797.24  2  2  3        7.0
# 3        12349.0       20         73        1757.55  3  2  3        8.0
# 4        12350.0      312         17         334.40  1  1  1        3.0
# ...          ...      ...        ...            ... .. .. ..        ...
# 4286     18280.0      161         10         180.60  1  1  1        3.0
# 4287     18281.0        5          7          80.82  3  1  1        5.0
# 4288     18282.0       94         13         176.60  2  1  1        4.0
# 4289     18283.0       11        756        2094.88  3  3  3        9.0
# 4290     18287.0        1         70        1837.28  3  2  3        8.0
#
#      RFM_Level
# 0         Đồng
# 1         Vàng
# 2         Vàng
# 3         Vàng
# 4         Đồng
# ...        ...
# 4286      Đồng
# 4287       Bạc
# 4288      Đồng
# 4289      Vàng
# 4290      Vàng
#
# [4291 rows x 9 columns]

# %%
datamart.to_csv('1.csv')

# %%
rfm_level_agg
# Out:
#   RFM_Level  RecencyMean  FrequencyMean  MonetaryMean  Count  Percent  \
# 0       Bạc         95.0           39.0         685.0   1266    29.50
# 1      Vàng         33.0          179.0        3775.0   1809    42.16
# 2      Đồng        180.0           15.0         220.0   1216    28.34
#
#    Percent_Recency  Percent_Frequency  Percent_MonetaryValue
# 0             2.21               0.91                  15.96
# 1             0.77               4.17                  87.97
# 2             4.19               0.35                   5.13
